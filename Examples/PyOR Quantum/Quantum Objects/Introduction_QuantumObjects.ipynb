# %% [markdown]
# # PyOR Quantum
# ### Author: Vineeth Thalakottoor
# ### Introduction to Quantum Objects

# %%
SourcePath = '/media/HD2/Vineeth/PostDoc_Simulations/Github/PyOR_V1/Source'
import sys
sys.path.append(SourcePath)

from PythonOnResonance_MagneticResonance import MagneticResonance 
from PythonOnResonance_Quantum import QunObj, QuantumLibrary, QuantumSystem

import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib ipympl
import sympy as sp
from sympy import *

# %% [markdown]
# ### Define State and Operator

# %%
vec = QunObj([[1], [0]],PrintDefault=True) # Vector (ket)
op = QunObj([[5.0, 0],[0.0,-0.5]],PrintDefault=True) # Matrix (operator)
# Out:
# Quantum object: shape=(2, 1), type='ket', data type='complex128'
# Quantum object: shape=(2, 2), type='operator', data type='complex128'

# %% [markdown]
# ### Ket

# %%
vec.matrix # Attribute : matrix - show matrix form using sympy
# Out:
# Matrix([
# [1.0],
# [  0]])

# %%
vec.type # Attribute : type - show the type of the object (ket, bra or operator)
# Out:
# 'ket'

# %%
vec.data # Attribute : data - show matrix form using numpy, as array
# Out:
# array([[1.+0.j],
#        [0.+0.j]])

# %%
vec.datatype # Attribute : datatype - show the data typer of the array
# Out:
# dtype('complex128')

# %%
vec1 = vec.Rotate(180,op) # Method : Rotate - Rotate the object

# %%
vec1.matrix
# Out:
# Matrix([
# [-1.0],
# [   0]])

# %%
vec1.Norm() # Method : Norm - Norml of the object
# Out:
# 1.0

# %%
vec1.Normalize() # Method : Normalize - Normalize the object

# %%
vec1.Conjugate() # Method : Conjugate - Conjugate of the object

# %%
vec1.Tranpose() # Method : Transpose - Transpose of the object

# %%
op1 = vec1.OuterProduct(vec1) # Method : OuterProduct - take the outerproduct between two object

# %%
op1.matrix
# Out:
# Matrix([
# [1.0, 0],
# [  0, 0]])

# %%
op1.type
# Out:
# 'operator'

# %%
op1.InnerProduct(op1) # Method : InnerProduct
# Out:
# (1+0j)

# %%
vec1.InnerProduct(vec1) # Method : InnerProduct
# Out:
# (1+0j)

# %% [markdown]
# ### Bra

# %%
bra = vec.Adjoint() # Method : Adjoint - Adjoint of the object

# %%
bra.matrix
# Out:
# Matrix([[1.0, 0]])

# %% [markdown]
# ### Operator

# %%
op.matrix
# Out:
# Matrix([
# [5.0,    0],
# [  0, -0.5]])

# %%
op.type
# Out:
# 'operator'

# %%
op.Hermitian() # Method : Hermitian - Chech if the object is hermitian
# Out:
# True

# %%
op.Positive() # Method : Positive - Chech if the object has positive diagonal elements
# Out:
# False

# %%
op1.Purity() # Method : Putiry
# Out:
# (1+0j)

# %%
op.Expm().matrix # Method : Expm - exponential of a matrix
# Out:
# Matrix([
# [148.413159102577,                 0],
# [               0, 0.606530659712633]])

# %%
vec2 = op * vec # Multiply two objects

# %%
vec2.matrix
# Out:
# Matrix([
# [5.0],
# [  0]])

# %%
vec3 = 5 * vec # Add a object with a scalar

# %%
vec3.matrix
# Out:
# Matrix([
# [5.0],
# [  0]])

# %%
op2 = op1 + op # Add two objects

# %%
op2.matrix
# Out:
# Matrix([
# [6.0,    0],
# [  0, -0.5]])
